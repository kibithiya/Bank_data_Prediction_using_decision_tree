# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("bank.csv")
df
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 0       unknown    5   may      1042         1     -1         0  unknown
# 1       unknown    5   may      1467         1     -1         0  unknown
# 2       unknown    5   may      1389         1     -1         0  unknown
# 3       unknown    5   may       579         1     -1         0  unknown
# 4       unknown    5   may       673         2     -1         0  unknown
# ...         ...  ...   ...       ...       ...    ...       ...      ...
# 11157  cellular   20   apr       257         1     -1         0  unknown
# 11158   unknown   16   jun        83         4     -1         0  unknown
# 11159  cellular   19   aug       156         2     -1         0  unknown
# 11160  cellular    8   may         9         2    172         5  failure
# 11161  cellular    9   jul       628         1     -1         0  unknown
#
#       deposit
# 0         yes
# 1         yes
# 2         yes
# 3         yes
# 4         yes
# ...       ...
# 11157      no
# 11158      no
# 11159      no
# 11160      no
# 11161      no
#
# [11162 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# max      854.000000     58.000000

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %%
sns.pairplot(df)
plt.show()

# %%
def con(x):
    if x == 'no':
        return 1
    elif x == 'yes':
        return 0
    else:
        return x  # Leave other values unchanged

# Apply the function to all columns of the DataFrame
df_replaced = df.map(con)

# %%
df=df_replaced
df
# Out:
#        age          job  marital  education  default  balance  housing  loan  \
# 0       59       admin.  married  secondary        1     2343        0     1
# 1       56       admin.  married  secondary        1       45        1     1
# 2       41   technician  married  secondary        1     1270        0     1
# 3       55     services  married  secondary        1     2476        0     1
# 4       54       admin.  married   tertiary        1      184        1     1
# ...    ...          ...      ...        ...      ...      ...      ...   ...
# 11157   33  blue-collar   single    primary        1        1        0     1
# 11158   39     services  married  secondary        1      733        1     1
# 11159   32   technician   single  secondary        1       29        1     1
# 11160   43   technician  married  secondary        1        0        1     0
# 11161   34   technician  married  secondary        1        0        1     1
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 0       unknown    5   may      1042         1     -1         0  unknown
# 1       unknown    5   may      1467         1     -1         0  unknown
# 2       unknown    5   may      1389         1     -1         0  unknown
# 3       unknown    5   may       579         1     -1         0  unknown
# 4       unknown    5   may       673         2     -1         0  unknown
# ...         ...  ...   ...       ...       ...    ...       ...      ...
# 11157  cellular   20   apr       257         1     -1         0  unknown
# 11158   unknown   16   jun        83         4     -1         0  unknown
# 11159  cellular   19   aug       156         2     -1         0  unknown
# 11160  cellular    8   may         9         2    172         5  failure
# 11161  cellular    9   jul       628         1     -1         0  unknown
#
#        deposit
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 11157        1
# 11158        1
# 11159        1
# 11160        1
# 11161        1
#
# [11162 rows x 17 columns]

# %%
df['poutcome'].unique()
# Out:
# array(['unknown', 'other', 'failure', 'success'], dtype=object)

# %%
df['job'].unique()
# Out:
# array(['admin.', 'technician', 'services', 'management', 'retired',
#        'blue-collar', 'unemployed', 'entrepreneur', 'housemaid',
#        'unknown', 'self-employed', 'student'], dtype=object)

# %%
df.drop(columns=["marital"],inplace=True)

# %%
df.drop(columns=["education"],inplace=True)
df.drop(columns=["contact"],inplace=True)
df.drop(columns=["month"],inplace=True)
df
# Out:
#        age          job  default  balance  housing  loan  day  duration  \
# 0       59       admin.        1     2343        0     1    5      1042
# 1       56       admin.        1       45        1     1    5      1467
# 2       41   technician        1     1270        0     1    5      1389
# 3       55     services        1     2476        0     1    5       579
# 4       54       admin.        1      184        1     1    5       673
# ...    ...          ...      ...      ...      ...   ...  ...       ...
# 11157   33  blue-collar        1        1        0     1   20       257
# 11158   39     services        1      733        1     1   16        83
# 11159   32   technician        1       29        1     1   19       156
# 11160   43   technician        1        0        1     0    8         9
# 11161   34   technician        1        0        1     1    9       628
#
#        campaign  pdays  previous poutcome  deposit
# 0             1     -1         0  unknown        0
# 1             1     -1         0  unknown        0
# 2             1     -1         0  unknown        0
# 3             1     -1         0  unknown        0
# 4             2     -1         0  unknown        0
# ...         ...    ...       ...      ...      ...
# 11157         1     -1         0  unknown        1
# 11158         4     -1         0  unknown        1
# 11159         2     -1         0  unknown        1
# 11160         2    172         5  failure        1
# 11161         1     -1         0  unknown        1
#
# [11162 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['age', 'job', 'default', 'balance', 'housing', 'loan', 'day',
#        'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %%
df=pd.get_dummies(df,drop_first=True)
df
# Out:
#        age  default  balance  housing  loan  day  duration  campaign  pdays  \
# 0       59        1     2343        0     1    5      1042         1     -1
# 1       56        1       45        1     1    5      1467         1     -1
# 2       41        1     1270        0     1    5      1389         1     -1
# 3       55        1     2476        0     1    5       579         1     -1
# 4       54        1      184        1     1    5       673         2     -1
# ...    ...      ...      ...      ...   ...  ...       ...       ...    ...
# 11157   33        1        1        0     1   20       257         1     -1
# 11158   39        1      733        1     1   16        83         4     -1
# 11159   32        1       29        1     1   19       156         2     -1
# 11160   43        1        0        1     0    8         9         2    172
# 11161   34        1        0        1     1    9       628         1     -1
#
#        previous  ...  job_retired  job_self-employed  job_services  \
# 0             0  ...        False              False         False
# 1             0  ...        False              False         False
# 2             0  ...        False              False         False
# 3             0  ...        False              False          True
# 4             0  ...        False              False         False
# ...         ...  ...          ...                ...           ...
# 11157         0  ...        False              False         False
# 11158         0  ...        False              False          True
# 11159         0  ...        False              False         False
# 11160         5  ...        False              False         False
# 11161         0  ...        False              False         False
#
#        job_student  job_technician  job_unemployed  job_unknown  \
# 0            False           False           False        False
# 1            False           False           False        False
# 2            False            True           False        False
# 3            False           False           False        False
# 4            False           False           False        False
# ...            ...             ...             ...          ...
# 11157        False           False           False        False
# 11158        False           False           False        False
# 11159        False            True           False        False
# 11160        False            True           False        False
# 11161        False            True           False        False
#
#        poutcome_other  poutcome_success  poutcome_unknown
# 0               False             False              True
# 1               False             False              True
# 2               False             False              True
# 3               False             False              True
# 4               False             False              True
# ...               ...               ...               ...
# 11157           False             False              True
# 11158           False             False              True
# 11159           False             False              True
# 11160           False             False             False
# 11161           False             False              True
#
# [11162 rows x 25 columns]

# %%
plt.figure(figsize=(20,14))
sns.heatmap(df.corr(),annot=True,fmt=".1f")
plt.show()

# %%
x=df.drop(columns=["deposit"])
x
# Out:
#        age  default  balance  housing  loan  day  duration  campaign  pdays  \
# 0       59        1     2343        0     1    5      1042         1     -1
# 1       56        1       45        1     1    5      1467         1     -1
# 2       41        1     1270        0     1    5      1389         1     -1
# 3       55        1     2476        0     1    5       579         1     -1
# 4       54        1      184        1     1    5       673         2     -1
# ...    ...      ...      ...      ...   ...  ...       ...       ...    ...
# 11157   33        1        1        0     1   20       257         1     -1
# 11158   39        1      733        1     1   16        83         4     -1
# 11159   32        1       29        1     1   19       156         2     -1
# 11160   43        1        0        1     0    8         9         2    172
# 11161   34        1        0        1     1    9       628         1     -1
#
#        previous  ...  job_retired  job_self-employed  job_services  \
# 0             0  ...        False              False         False
# 1             0  ...        False              False         False
# 2             0  ...        False              False         False
# 3             0  ...        False              False          True
# 4             0  ...        False              False         False
# ...         ...  ...          ...                ...           ...
# 11157         0  ...        False              False         False
# 11158         0  ...        False              False          True
# 11159         0  ...        False              False         False
# 11160         5  ...        False              False         False
# 11161         0  ...        False              False         False
#
#        job_student  job_technician  job_unemployed  job_unknown  \
# 0            False           False           False        False
# 1            False           False           False        False
# 2            False            True           False        False
# 3            False           False           False        False
# 4            False           False           False        False
# ...            ...             ...             ...          ...
# 11157        False           False           False        False
# 11158        False           False           False        False
# 11159        False            True           False        False
# 11160        False            True           False        False
# 11161        False            True           False        False
#
#        poutcome_other  poutcome_success  poutcome_unknown
# 0               False             False              True
# 1               False             False              True
# 2               False             False              True
# 3               False             False              True
# 4               False             False              True
# ...               ...               ...               ...
# 11157           False             False              True
# 11158           False             False              True
# 11159           False             False              True
# 11160           False             False             False
# 11161           False             False              True
#
# [11162 rows x 24 columns]

# %%
y=df["deposit"]
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 11157    1
# 11158    1
# 11159    1
# 11160    1
# 11161    1
# Name: deposit, Length: 11162, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_scaled=scaler.fit_transform(x)
x_scaled
# Out:
# array([[ 1.49150488,  0.12361659,  0.25252514, ..., -0.22481365,
#         -0.32578241,  0.58362637],
#        [ 1.23967567,  0.12361659, -0.4599736 , ..., -0.22481365,
#         -0.32578241,  0.58362637],
#        [-0.0194704 ,  0.12361659, -0.0801603 , ..., -0.22481365,
#         -0.32578241,  0.58362637],
#        ...,
#        [-0.77495804,  0.12361659, -0.46493443, ..., -0.22481365,
#         -0.32578241,  0.58362637],
#        [ 0.14841574,  0.12361659, -0.47392593, ..., -0.22481365,
#         -0.32578241, -1.71342496],
#        [-0.6070719 ,  0.12361659, -0.47392593, ..., -0.22481365,
#         -0.32578241,  0.58362637]])

# %%
pd.DataFrame(x_scaled,columns=x.columns)
# Out:
#             age   default   balance   housing      loan       day  duration  \
# 0      1.491505  0.123617  0.252525 -1.055280  0.387923 -1.265746  1.930226
# 1      1.239676  0.123617 -0.459974  0.947616  0.387923 -1.265746  3.154612
# 2     -0.019470  0.123617 -0.080160 -1.055280  0.387923 -1.265746  2.929901
# 3      1.155733  0.123617  0.293762 -1.055280  0.387923 -1.265746  0.596366
# 4      1.071790  0.123617 -0.416876  0.947616  0.387923 -1.265746  0.867171
# ...         ...       ...       ...       ...       ...       ...       ...
# 11157 -0.691015  0.123617 -0.473616 -1.055280  0.387923  0.515650 -0.331287
# 11158 -0.187357  0.123617 -0.246658  0.947616  0.387923  0.040612 -0.832564
# 11159 -0.774958  0.123617 -0.464934  0.947616  0.387923  0.396891 -0.622258
# 11160  0.148416  0.123617 -0.473926  0.947616 -2.577830 -0.909466 -1.045752
# 11161 -0.607072  0.123617 -0.473926  0.947616  0.387923 -0.790707  0.737530
#
#        campaign     pdays  previous  ...  job_retired  job_self-employed  \
# 0     -0.554168 -0.481184 -0.363260  ...    -0.273721          -0.194036
# 1     -0.554168 -0.481184 -0.363260  ...    -0.273721          -0.194036
# 2     -0.554168 -0.481184 -0.363260  ...    -0.273721          -0.194036
# 3     -0.554168 -0.481184 -0.363260  ...    -0.273721          -0.194036
# 4     -0.186785 -0.481184 -0.363260  ...    -0.273721          -0.194036
# ...         ...       ...       ...  ...          ...                ...
# 11157 -0.554168 -0.481184 -0.363260  ...    -0.273721          -0.194036
# 11158  0.547981 -0.481184 -0.363260  ...    -0.273721          -0.194036
# 11159 -0.186785 -0.481184 -0.363260  ...    -0.273721          -0.194036
# 11160 -0.186785  1.109571  1.818332  ...    -0.273721          -0.194036
# 11161 -0.554168 -0.481184 -0.363260  ...    -0.273721          -0.194036
#
#        job_services  job_student  job_technician  job_unemployed  job_unknown  \
# 0         -0.300242    -0.182557       -0.441818        -0.18177    -0.079441
# 1         -0.300242    -0.182557       -0.441818        -0.18177    -0.079441
# 2         -0.300242    -0.182557        2.263377        -0.18177    -0.079441
# 3          3.330642    -0.182557       -0.441818        -0.18177    -0.079441
# 4         -0.300242    -0.182557       -0.441818        -0.18177    -0.079441
# ...             ...          ...             ...             ...          ...
# 11157     -0.300242    -0.182557       -0.441818        -0.18177    -0.079441
# 11158      3.330642    -0.182557       -0.441818        -0.18177    -0.079441
# 11159     -0.300242    -0.182557        2.263377        -0.18177    -0.079441
# 11160     -0.300242    -0.182557        2.263377        -0.18177    -0.079441
# 11161     -0.300242    -0.182557        2.263377        -0.18177    -0.079441
#
#        poutcome_other  poutcome_success  poutcome_unknown
# 0           -0.224814         -0.325782          0.583626
# 1           -0.224814         -0.325782          0.583626
# 2           -0.224814         -0.325782          0.583626
# 3           -0.224814         -0.325782          0.583626
# 4           -0.224814         -0.325782          0.583626
# ...               ...               ...               ...
# 11157       -0.224814         -0.325782          0.583626
# 11158       -0.224814         -0.325782          0.583626
# 11159       -0.224814         -0.325782          0.583626
# 11160       -0.224814         -0.325782         -1.713425
# 11161       -0.224814         -0.325782          0.583626
#
# [11162 rows x 24 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5)

# %%
x_train.size
# Out:
# 133944

# %%
y_train.size
# Out:
# 5581

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier(max_depth=3,min_samples_split=2,criterion="gini")

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7679627306934241

# %%
c=confusion_matrix(y_test,y_pred)
c
# Out:
# array([[1760,  884],
#        [ 411, 2526]], dtype=int64)

# %%
plt.figure(plt.figure(figsize=(5,4)))
sns.heatmap(c,annot=True,fmt=".1f")
# Out:
# <Axes: >
